# %% [markdown]
#                                       Самостійна робота №1
#                                       Варіант №1
#                                       Пустовгара Іллі
#                                       ПМ-21мп

# %% [markdown]
# Загальні завдання для всіх варіантів:
# Швидкий погляд на дані:
# 1. Завантажте набір даних.
# 2. Виведіть заголовок таблиці (перші 5 записів).
# 3. Скільки рядків і стовпців в таблиці?
# 4. Які назви стовпців?
# 5. Які типи даних у різних стовпців?
# 6. Скільки в кожному з них унікальних значень?
# 7. Скільки пропущених значень?

# %% [markdown]
# 1 Завантажив набір даних , бібліотеки pd i nd , файл la-crimes.csv

# %%
import pandas as pd
import numpy as np


df = pd.read_csv('https://raw.githubusercontent.com/IllyaPystovga/lab/main/lab1')

# %% [markdown]
# Вивів перші 5 записів.

# %%
df[:5]
# Out:
#    Unnamed: 0  DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 0      246798  100509940    2010-04-25    2010-04-25           1630        5
# 1     1179557  151917155    2015-08-27    2015-08-27            430       19
# 2     1527668  172008833    2017-04-04    2017-04-03           1000       20
# 3       94687  101117037    2010-08-03    2010-08-02           2120       11
# 4     1376548  161711262    2016-06-02    2016-06-02           1240       17
#
#     Area Name  Reporting District  Crime Code  \
# 0      Harbor                 529         740
# 1     Mission                1917         626
# 2     Olympic                2021         310
# 3   Northeast                1107         624
# 4  Devonshire                1764         210
#
#                               Crime Code Description  ...  \
# 0  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...
# 1                  INTIMATE PARTNER - SIMPLE ASSAULT  ...
# ...

# %% [markdown]
# Визначів розмірність таблиці.

# %%
df.shape
# Out:
# (39608, 27)

# %% [markdown]
# Визначив назви стовпців , також визначив типи даних стовпців.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39608 entries, 0 to 39607
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              39608 non-null  int64
#  1   DR Number               39608 non-null  int64
#  2   Date Reported           39608 non-null  object
#  3   Date Occurred           39608 non-null  object
#  4   Time Occurred           39608 non-null  int64
#  5   Area ID                 39608 non-null  int64
#  6   Area Name               39608 non-null  object
#  7   Reporting District      39608 non-null  int64
#  8   Crime Code              39608 non-null  int64
#  9   Crime Code Description  39601 non-null  object
#  10  MO Codes                35317 non-null  object
#  11  Victim Age              36388 non-null  float64
#  12  Victim Sex              35977 non-null  object
#  13  Victim Descent          35976 non-null  object
# ...

# %% [markdown]
# Вивів кількість унікальних значень в стовпцях.

# %%
columns = df.columns;
i = 0;

for name in columns:

  print('column =',i + 1);
  uniqueValues = df[name].unique();
  print('unique Values',uniqueValues.size);
  print('***************');

  i += 1;
# Out:
# column = 1
# unique Values 39608
# ***************
# column = 2
# unique Values 39608
# ***************
# column = 3
# unique Values 2809
# ***************
# column = 4
# unique Values 2808
# ***************
# column = 5
# unique Values 900
# ***************
# column = 6
# unique Values 21
# ***************
# column = 7
# unique Values 21
# ***************
# column = 8
# unique Values 1135
# ***************
# column = 9
# unique Values 115
# ***************
# column = 10
# unique Values 114
# ***************
# column = 11
# unique Values 14020
# ***************
# column = 12
# unique Values 91
# ***************
# column = 13
# unique Values 5
# ***************
# column = 14
# unique Values 18
# ***************
# column = 15
# unique Values 190
# ***************
# column = 16
# unique Values 171
# ***************
# column = 17
# unique Values 66
# ***************
# column = 18
# unique Values 66
# ***************
# column = 19
# unique Values 6
# ***************
# column = 20
# ...

# %% [markdown]
# Виявив наявність пропущених значень.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# DR Number                     0
# Date Reported                 0
# Date Occurred                 0
# Time Occurred                 0
# Area ID                       0
# Area Name                     0
# Reporting District            0
# Crime Code                    0
# Crime Code Description        7
# MO Codes                   4291
# Victim Age                 3220
# Victim Sex                 3631
# Victim Descent             3632
# Premise Code                  3
# Premise Description          72
# Weapon Used Code          26530
# Weapon Description        26530
# Status Code                   0
# Status Description            0
# Crime Code 1                  0
# Crime Code 2              37125
# Crime Code 3              39558
# Crime Code 4              39606
# Address                       0
# Cross Street              32978
# Location                      1
# dtype: int64

# %% [markdown]
# Перевіпив наявність пропусків.

# %%
df.isnull().any()
# Out:
# Unnamed: 0                False
# DR Number                 False
# Date Reported             False
# Date Occurred             False
# Time Occurred             False
# Area ID                   False
# Area Name                 False
# Reporting District        False
# Crime Code                False
# Crime Code Description     True
# MO Codes                   True
# Victim Age                 True
# Victim Sex                 True
# Victim Descent             True
# Premise Code               True
# Premise Description        True
# Weapon Used Code           True
# Weapon Description         True
# Status Code               False
# Status Description        False
# Crime Code 1              False
# Crime Code 2               True
# Crime Code 3               True
# Crime Code 4               True
# Address                   False
# Cross Street               True
# Location                   True
# dtype: bool

# %% [markdown]
# Варіант 1
# Набір даних: злочинність в Лос-Анджелесі (la-crime.csv).
# Аналіз даних:
# 1. У наборі даних є інформація про вік, стать, і походження кожної  жертви. Люди якого походження найчастіше є жертвами злочинів?
# 2. Чи вірно, що жінки частіше виявляються жертвами в порівнянні з  чоловіками?
# 3. Вивчіть розподіл кількості злочинів за віком. Яка тенденція? Люди  якого віку найчастіше піддаються злочинам? Чи є локальні мінімуми?  Використовуйте тип графіків hist.
# 4. Як відрізняється ймовірність для жінок і чоловіків стати жертвою в  залежності від віку? Побудуйте візуалізацію.
# 5. В якому віковому проміжку чоловіки частіше стають жертвами  злочинів?

# %% [markdown]
# 1. Hайчастіше жертвами злочинів були іспанці/латиноамериканці/мексиканці.

# %%
df['Victim Descent'].value_counts().plot(kind="pie", figsize=(10, 10), fontsize=16);

# %% [markdown]
# 2. Ні , чоловіки виявляється жертвами частіше.

# %%
df['Victim Sex'].value_counts().plot(kind="pie", figsize=(10, 10), fontsize=16);

# %% [markdown]
# 3. Люди 20 - 40 років найчастіше піддаються злочинам.
# Так є локальні мінімуми, від народження і до 9 років.
# Також люди 65+ років.

# %%
df['Victim Age'].plot(kind="hist", figsize=(15, 5));

# %%
df['Victim Age'].value_counts();
value_counts = df['Victim Age'];
print(value_counts);
# Out:
# 0        70.0
# 1        54.0
# 2        55.0
# 3        22.0
# 4         NaN
#          ...
# 39603    51.0
# 39604    37.0
# 39605    31.0
# 39606    12.0
# 39607    54.0
# Name: Victim Age, Length: 39608, dtype: float64

# %% [markdown]
# Ми бачимо, що чоловіків фактично значно більше, ніж жінок.
# Тоді було б логічно, що чоловіки представляють більшу кількість тих, хто стали жертвою , оскільки їх було більше насамперед

# %%
df[df['Victim Sex'] == 'M']['Victim Age'].plot(kind="hist", figsize=(15, 5));
df[df['Victim Sex'] == 'F']['Victim Age'].plot(kind="hist", figsize=(15, 5));

# %% [markdown]
#  5. В віковому проміжку 20 - 40 років чоловіки частіше стають жертвами злочинів

# %%
df[df['Victim Sex'] == 'M']['Victim Age'].plot(kind="hist", figsize=(15, 5));
